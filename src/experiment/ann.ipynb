# %%
import sys
import os
sys.path.append(os.path.abspath('../../..'))

# %%
from src.utils.helpers import create_dataset_evaluation
# Out:
# WARNING:tensorflow:From c:\Users\tomko\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = create_dataset_evaluation(
    configs=[
        # "../../models/ann_configs/capacitor_config.json",
        "../../models/ann_configs/simplecooling_config.json", 
        "../../models/ann_configs/simpleheating_config.json", 
        "../../models/ann_configs/coolingnetw_config.json", 
        "../../models/ann_configs/osci_config.json", 
        "../../models/ann_configs/chua_config.json"
    ],
    train_datasets=[
        # "../../data/paper_data/capacitor/",
        "../../data/paper_data/simplecooling/",
        "../../data/paper_data/simpleheating/",
        "../../data/paper_data/coolingnetw/",
        "../../data/paper_data/osci/",
        "../../data/paper_data/chua/"
    ],
    test_datasets=[
        # "../../data/paper_data/capacitor/test_data/",
        "../../data/paper_data/simplecooling/test_data/",
        "../../data/paper_data/simpleheating/test_data/",
        "../../data/paper_data/coolingnetw/test_data/",
        "../../data/paper_data/osci/test_data/",
        "../../data/paper_data/chua/test_data/"
    ],
    n_array=[1, 25, 1000]
)
# Out:
# Number of training samples: 70000
# WARNING:tensorflow:From c:\Users\tomko\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# 2025-01-16 10:02:26,070 - WARNING - From c:\Users\tomko\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From c:\Users\tomko\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 2025-01-16 10:02:26,222 - WARNING - From c:\Users\tomko\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Model: "sequential"
# ...

# %%
df
