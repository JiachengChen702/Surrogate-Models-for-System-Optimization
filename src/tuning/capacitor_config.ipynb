# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import tensorflow as tf
import tensorflow.keras as keras
print(tf.__version__)
# Out:
# 2.15.0

# %%
from src.models.ANN import ANN
from src.utils.preprocessing import Preprocessing
from src.tuning.Hyperband import tune_model

# %%
preprocessor = Preprocessing()
preprocessor.read_csv(folder_name="../paper_data/capacitor")  
preprocessor.split_dataset(train_split_ratio=0.7)
# Out:
# Number of training samples: 70000

# %%
config = tune_model(preprocessor)
# Out:
# 2025-01-21 10:41:04,039 - INFO - Starting model tuning process...
# Reloading Tuner from ann/capacitor2/tuner0.json
# 2025-01-21 10:41:05,507 - INFO - Best Configuration from Hyperband: {'input_shape': (4,), 'neurons_input': 4, 'activation_input': 'linear', 'anzahl_hidden': 1, 'neurons_hidden': [14], 'activation_hidden': ['relu'], 'neurons_output': 4, 'activation_output': 'linear', 'optimizer': 'nadam', 'learning_rate': 0.001977417850651913, 'loss': 'mean_squared_error', 'metrics': ['mse']}
