# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import tensorflow as tf
import tensorflow.keras as keras
print(tf.__version__)
# Out:
# 2025-01-20 18:21:11.452303: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-20 18:21:11.452329: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-20 18:21:11.453127: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-20 18:21:11.458360: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from src.models.ANN import ANN
from src.utils.preprocessing import Preprocessing
from src.tuning.Hyperband import tune_model

# %%
preprocessor = Preprocessing()
preprocessor.read_csv(folder_name="../paper_data/coolingnetw")  
preprocessor.split_dataset(train_split_ratio=0.7)
# Out:
# Number of training samples: 70000

# %%
config = tune_model(preprocessor)
# Out:
# Trial 338 Complete [00h 04m 30s]
# val_loss: 0.016043327748775482
#
# Best val_loss So Far: 0.011126229539513588
# Total elapsed time: 03h 37m 57s
#
# Search: Running Trial #339
#
# Value             |Best Value So Far |Hyperparameter
# 64                |37                |neurons_hidden
# linear            |linear            |activation
# 2                 |2                 |anzahl_hidden
# nadam             |adam              |optimizer
# 5.1122e-05        |0.0012342         |learning_rate
# 100               |33                |neurons_hidden_0
# relu              |relu              |activation_hidden_0
# 14                |36                |neurons_hidden_1
# relu              |relu              |activation_hidden_1
# 25                |42                |neurons_hidden_2
# relu              |relu              |activation_hidden_2
# 75                |53                |neurons_hidden_3
# relu              |relu              |activation_hidden_3
# ...
