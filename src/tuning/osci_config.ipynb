# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import tensorflow as tf
import tensorflow.keras as keras
print(tf.__version__)
# Out:
# 2025-01-21 11:03:37.879206: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-21 11:03:37.879233: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-21 11:03:37.880052: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-21 11:03:37.885019: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-21 11:03:39.654333: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.15.0

# %%
from src.models.ANN import ANN
from src.utils.preprocessing import Preprocessing
from src.tuning.Hyperband import tune_model

# %%
preprocessor = Preprocessing()
preprocessor.read_csv(folder_name="../paper_data/osci")  
#preprocessor.read_csv(folder_name="train_data/new_data")
preprocessor.split_dataset(train_split_ratio=0.7)
# Out:
# Number of training samples: 70000

# %%
config = tune_model(preprocessor,write_folder="osci3")
# Out:
# 2025-01-21 11:03:52,747 - INFO - Starting model tuning process...
# Reloading Tuner from ann/osci3/tuner0.json
# 2025-01-21 11:03:53,925 - INFO - Best Configuration from Hyperband: {'input_shape': (8,), 'neurons_input': 8, 'activation_input': 'linear', 'anzahl_hidden': 2, 'neurons_hidden': [51, 32], 'activation_hidden': ['relu', 'relu'], 'neurons_output': 8, 'activation_output': 'linear', 'optimizer': 'adam', 'learning_rate': 0.0019606597714987473, 'loss': 'mean_squared_error', 'metrics': ['mse']}
